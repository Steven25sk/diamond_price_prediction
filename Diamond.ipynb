# %% [markdown]
# # 1. Perkenalan

# %% [markdown]
# - Nama :
# - Batch :
# - Dataset :
# - Objective :

# %% [markdown]
# # 2. Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 3. Data Loading

# %%
# Load Dataset

data = pd.read_csv('Diamonds Prices2022.csv')
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 53938  6.12  3.74
# 53939  5.87  3.64
# 53940  5.74  3.49
# 53941  5.73  3.43
# 53942  5.76  3.47

# %%
# Check Dataset - 1

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# Data terdiri dari 11 column :
#
# - `8 Integer`
# - `3 String`

# %%
# Check Dataset - 2

data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean   26972.000000      0.797935     61.749322     57.457251   3932.734294
# std    15572.147122      0.473999      1.432626      2.234549   3989.338447
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13486.500000      0.400000     61.000000     56.000000    950.000000
# 50%    26972.000000      0.700000     61.800000     57.000000   2401.000000
# 75%    40457.500000      1.040000     62.500000     59.000000   5324.000000
# max    53943.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53943.000000  53943.000000  53943.000000
# mean       5.731158      5.734526      3.538730
# std        1.121730      1.142103      0.705679
# min        0.000000      0.000000      0.000000
# ...

# %%
# Check Missing Values

data.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# Tidak ada Missing Values

# %% [markdown]
# # 4. Exploratory Data Analysis

# %%
categorical_features=[feature for feature in data.columns if data[feature].dtypes=='O']
print('number of categorical variables:',len(categorical_features))
# Out:
# number of categorical variables: 3

# %%
for feature in categorical_features:
  plt.figure(figsize=(7,7))
  plt.pie(x=data[feature].value_counts(),autopct='%1.1f%%',pctdistance=1.1,
          wedgeprops={'linewidth':1.0,'edgecolor':'black'},
          textprops={'color':'black','fontsize':10},
          )
  plt.legend(labels=data[feature].value_counts().index)
  plt.title(feature,fontsize=20)

# %% [markdown]
# # 5. Data Preprocessing

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5.1. Get Data for Model Inference

# %%
# Get Data for model Inference

data_inf = data.sample(10, random_state=25)
data_inf
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 50616       50617   0.25       Good     D     VS1   57.6   60.0    399  4.15
# 8290         8291   1.03    Premium     H     SI1   60.7   60.0   4384  6.61
# 14520       14521   1.01    Premium     G     VS2   61.6   61.0   5864  6.46
# 4275         4276   1.00    Premium     G     SI2   60.2   58.0   3584  6.55
# 25115       25116   1.78  Very Good     F     SI1   60.6   57.0  13659  7.89
# 10106       10107   1.20    Premium     J     SI1   60.0   61.0   4717  6.89
# 52998       52999   0.78      Ideal     E     SI2   61.2   54.0   2596  5.96
# 20738       20739   1.61    Premium     I     SI1   62.0   58.0   8978  7.46
# 5243         5244   1.00      Ideal     J     SI1   62.7   58.0   3788  6.35
# 30358       30359   0.31      Ideal     F     VS1   61.1   57.0    729  4.34
#
#           y     z
# 50616  4.18  2.40
# 8290   6.53  3.99
# 14520  6.36  3.95
# 4275   6.48  3.92
# 25115  7.94  4.80
# ...

# %%
# Remove Inference-Set from Dataset

data_train_test = data.drop(data_inf.index)
data_train_test
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# Reset Index

data_train_test.reset_index(drop=True, inplace=True)
data_inf.reset_index(drop=True, inplace=True)
data_inf
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0       50617   0.25       Good     D     VS1   57.6   60.0    399  4.15
# 1        8291   1.03    Premium     H     SI1   60.7   60.0   4384  6.61
# 2       14521   1.01    Premium     G     VS2   61.6   61.0   5864  6.46
# 3        4276   1.00    Premium     G     SI2   60.2   58.0   3584  6.55
# 4       25116   1.78  Very Good     F     SI1   60.6   57.0  13659  7.89
# 5       10107   1.20    Premium     J     SI1   60.0   61.0   4717  6.89
# 6       52999   0.78      Ideal     E     SI2   61.2   54.0   2596  5.96
# 7       20739   1.61    Premium     I     SI1   62.0   58.0   8978  7.46
# 8        5244   1.00      Ideal     J     SI1   62.7   58.0   3788  6.35
# 9       30359   0.31      Ideal     F     VS1   61.1   57.0    729  4.34
#
#       y     z
# 0  4.18  2.40
# 1  6.53  3.99
# 2  6.36  3.95
# 3  6.48  3.92
# 4  7.94  4.80
# 5  6.84  4.12
# 6  6.00  3.66
# 7  7.51  4.64
# 8  6.41  4.00
# ...

# %% [markdown]
# ## 5.2. Splitting between `X` (Features) and `y` (Target)

# %%
# Splitting between `X` (Features) and `y` (Target)

X = data_train_test.drop('price', axis=1)
y = data_train_test['price']
X
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98
# 1               2   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84
# 2               3   0.23       Good     E     VS1   56.9   65.0  4.05  4.07
# 3               4   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23
# 4               5   0.31       Good     J     SI2   63.3   58.0  4.34  4.35
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53928       53939   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12
# 53929       53940   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87
# 53930       53941   0.71    Premium     E     SI1   60.5   55.0  5.79  5.74
# 53931       53942   0.71    Premium     F     SI1   59.8   62.0  5.74  5.73
# 53932       53943   0.70  Very Good     E     VS2   60.5   59.0  5.71  5.76
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# ...

# %%
# Split between Train-Set and Test-Set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

print('Train Size : ', X_train.shape)
print('Test Size  : ', X_test.shape)
# Out:
# Train Size :  (43146, 10)
# Test Size  :  (10787, 10)

# %% [markdown]
# ## 5.3. Feature Selection

# %%
X_train.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['Unnamed: 0', 'carat', 'depth', 'table', 'x', 'y', 'z']

# %%
X_train = X_train[['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z']]

# %%
X_test = X_test[['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z']]

# %% [markdown]
# ## 5.4. Split between Numerical Columns and Categorical Columns

# %%
# Get Numerical Columns and Categorical Columns

num_columns = X_train.select_dtypes(include=np.number).columns.tolist()
cat_columns = X_train.select_dtypes(include=['object']).columns.tolist()

print('Numerical Columns   : ', num_columns)
print('Categorical Columns : ', cat_columns)
# Out:
# Numerical Columns   :  ['carat', 'depth', 'table', 'x', 'y', 'z']
# Categorical Columns :  ['cut', 'color', 'clarity']

# %%
# Split Train-Set and Test-Set based on Column Types

X_train_num = X_train[num_columns]
X_train_cat = X_train[cat_columns]

X_test_num = X_test[num_columns]
X_test_cat = X_test[cat_columns]

X_train_num
# Out:
#        carat  depth  table     x     y     z
# 23482   1.50   62.0   55.0  7.40  7.32  4.56
# 40641   0.50   62.5   57.0  5.04  5.07  3.16
# 26240   2.00   63.0   59.0  7.94  8.07  5.04
# 36438   0.31   62.1   54.0  4.37  4.33  2.70
# 24871   1.59   61.3   56.0  7.50  7.60  4.63
# ...      ...    ...    ...   ...   ...   ...
# 35702   0.30   60.9   57.0  4.35  4.32  2.64
# 26767   2.04   61.0   61.0  8.08  8.14  4.95
# 6618    1.10   62.8   57.0  6.56  6.63  4.14
# 24894   1.58   59.0   59.0  7.68  7.63  4.52
# 29828   0.24   60.7   58.0  4.03  4.01  2.44
#
# [43146 rows x 6 columns]

# %% [markdown]
# ## 5.5. Feature Scaling

# %%
X_train_num
# Out:
#        carat  depth  table     x     y     z
# 23482   1.50   62.0   55.0  7.40  7.32  4.56
# 40641   0.50   62.5   57.0  5.04  5.07  3.16
# 26240   2.00   63.0   59.0  7.94  8.07  5.04
# 36438   0.31   62.1   54.0  4.37  4.33  2.70
# 24871   1.59   61.3   56.0  7.50  7.60  4.63
# ...      ...    ...    ...   ...   ...   ...
# 35702   0.30   60.9   57.0  4.35  4.32  2.64
# 26767   2.04   61.0   61.0  8.08  8.14  4.95
# 6618    1.10   62.8   57.0  6.56  6.63  4.14
# 24894   1.58   59.0   59.0  7.68  7.63  4.52
# 29828   0.24   60.7   58.0  4.03  4.01  2.44
#
# [43146 rows x 6 columns]

# %%
X_train_num.describe()
# Out:
#               carat         depth         table             x             y  \
# count  43146.000000  43146.000000  43146.000000  43146.000000  43146.000000
# mean       0.798204     61.747107     57.458344      5.732301      5.736322
# std        0.473440      1.433184      2.244324      1.121229      1.148682
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.720000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        4.130000     79.000000     95.000000     10.140000     58.900000
#
#                   z
# count  43146.000000
# mean       3.539366
# std        0.707933
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.030000
# max       31.800000

# %% [markdown]
# Harus dilakukan `feature scaling` menggunakan `StandardScaler` karena data antara satu dengan yang lain berbeda jauh

# %%
# Feature Scaling using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train_num)

X_train_num_scaled = scaler.transform(X_train_num)
X_test_num_scaled = scaler.transform(X_test_num)
X_train_num_scaled
# Out:
# array([[0.3307888 , 0.52777778, 0.23076923, 0.72978304, 0.12427844,
#         0.14339623],
#        [0.07633588, 0.54166667, 0.26923077, 0.49704142, 0.0860781 ,
#         0.09937107],
#        [0.45801527, 0.55555556, 0.30769231, 0.78303748, 0.13701188,
#         0.15849057],
#        ...,
#        [0.22900763, 0.55      , 0.26923077, 0.6469428 , 0.11256367,
#         0.13018868],
#        [0.35114504, 0.44444444, 0.30769231, 0.75739645, 0.1295416 ,
#         0.14213836],
#        [0.01017812, 0.49166667, 0.28846154, 0.3974359 , 0.06808149,
#         0.07672956]])

# %% [markdown]
# ## 5.6. Feature Encoding

# %%
# Display `X_train_cat`

X_train_cat
# Out:
#              cut color clarity
# 23482      Ideal     E     SI1
# 40641      Ideal     E     SI2
# 26240  Very Good     H     SI2
# 36438      Ideal     D     VS2
# 24871      Ideal     D     SI1
# ...          ...   ...     ...
# 35702      Ideal     D     VS2
# 26767  Very Good     I     VS2
# 6618   Very Good     I     SI2
# 24894    Premium     D     SI1
# 29828    Premium     E    VVS1
#
# [43146 rows x 3 columns]

# %%
# Feature Encoding using Ordinal Encoder

from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],
                                     ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
                                     ['I1','SI2', 'SI1','VS2','VS1','VVS2', 'VVS1','IF']])
encoder.fit(X_train_cat)

X_train_cat_encoded = encoder.transform(X_train_cat)
X_test_cat_encoded = encoder.transform(X_test_cat)
X_train_cat_encoded
# Out:
# array([[4., 1., 2.],
#        [4., 1., 1.],
#        [2., 4., 1.],
#        ...,
#        [2., 5., 1.],
#        [3., 0., 2.],
#        [3., 1., 6.]])

# %% [markdown]
# ## 5.7. Concate between Numerical Columns and Categorical Columns

# %%
# Concate Columns

X_train_final = np.concatenate([X_train_num_scaled, X_train_cat_encoded], axis=1)
X_test_final = np.concatenate([X_test_num_scaled, X_test_cat_encoded], axis=1)
X_train_final
# Out:
# array([[0.3307888 , 0.52777778, 0.23076923, ..., 4.        , 1.        ,
#         2.        ],
#        [0.07633588, 0.54166667, 0.26923077, ..., 4.        , 1.        ,
#         1.        ],
#        [0.45801527, 0.55555556, 0.30769231, ..., 2.        , 4.        ,
#         1.        ],
#        ...,
#        [0.22900763, 0.55      , 0.26923077, ..., 2.        , 5.        ,
#         1.        ],
#        [0.35114504, 0.44444444, 0.30769231, ..., 3.        , 0.        ,
#         2.        ],
#        [0.01017812, 0.49166667, 0.28846154, ..., 3.        , 1.        ,
#         6.        ]])

# %%
# Create DataFrame of `X_train_final`

X_train_final_df = pd.DataFrame(X_train_final, columns=[num_columns + cat_columns])
X_train_final_df
# Out:
#           carat     depth     table         x         y         z  cut color  \
# 0      0.330789  0.527778  0.230769  0.729783  0.124278  0.143396  4.0   1.0
# 1      0.076336  0.541667  0.269231  0.497041  0.086078  0.099371  4.0   1.0
# 2      0.458015  0.555556  0.307692  0.783037  0.137012  0.158491  2.0   4.0
# 3      0.027990  0.530556  0.211538  0.430966  0.073514  0.084906  4.0   0.0
# 4      0.353690  0.508333  0.250000  0.739645  0.129032  0.145597  4.0   0.0
# ...         ...       ...       ...       ...       ...       ...  ...   ...
# 43141  0.025445  0.497222  0.269231  0.428994  0.073345  0.083019  4.0   0.0
# 43142  0.468193  0.500000  0.346154  0.796844  0.138200  0.155660  2.0   5.0
# 43143  0.229008  0.550000  0.269231  0.646943  0.112564  0.130189  2.0   5.0
# 43144  0.351145  0.444444  0.307692  0.757396  0.129542  0.142138  3.0   0.0
# 43145  0.010178  0.491667  0.288462  0.397436  0.068081  0.076730  3.0   1.0
#
#       clarity
# 0         2.0
# ...

# %% [markdown]
# # 6. Model Definition

# %%
# Training using Linear Regression

from sklearn.linear_model import LinearRegression 

model_lin_reg = LinearRegression()

# %% [markdown]
# # 7. Model Training

# %%
# Train the Model

model_lin_reg.fit(X_train_final, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 8. Model Evaluation

# %%
# Predict Train-Set and Test-Set

y_pred_train = model_lin_reg.predict(X_train_final)
y_pred_test = model_lin_reg.predict(X_test_final)

y_pred_train
# Out:
# array([10231.83237668,   886.36233463, 13298.14370211, ...,
#         4482.43483058, 11196.82269435,  1485.28171721])

# %%
# Display `y_train`

y_train
# Out:
# 23482    11489
# 40641     1154
# 26240    15694
# 36438      942
# 24871    13298
#          ...
# 35702      911
# 26767    16616
# 6618      4083
# 24894    13329
# 29828      710
# Name: price, Length: 43146, dtype: int64

# %%
# Model Evaluation using MAE

from sklearn.metrics import mean_absolute_error

print('Mean Absolute Error - Train Set : ', mean_absolute_error(y_train, y_pred_train))
print('Mean Absolute Error - Test Set  : ', mean_absolute_error(y_test, y_pred_test))
# Out:
# Mean Absolute Error - Train Set :  804.0030039856828
# Mean Absolute Error - Test Set  :  800.6456243787833

# %%
from sklearn.metrics import r2_score

print('R2 Score : ', r2_score(y_test, y_pred_test))
# Out:
# R2 Score :  0.9042157737776204

# %% [markdown]
# # 9. Model Inference

# %%
# Display Inference-Set

data_inf
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0       50617   0.25       Good     D     VS1   57.6   60.0    399  4.15
# 1        8291   1.03    Premium     H     SI1   60.7   60.0   4384  6.61
# 2       14521   1.01    Premium     G     VS2   61.6   61.0   5864  6.46
# 3        4276   1.00    Premium     G     SI2   60.2   58.0   3584  6.55
# 4       25116   1.78  Very Good     F     SI1   60.6   57.0  13659  7.89
# 5       10107   1.20    Premium     J     SI1   60.0   61.0   4717  6.89
# 6       52999   0.78      Ideal     E     SI2   61.2   54.0   2596  5.96
# 7       20739   1.61    Premium     I     SI1   62.0   58.0   8978  7.46
# 8        5244   1.00      Ideal     J     SI1   62.7   58.0   3788  6.35
# 9       30359   0.31      Ideal     F     VS1   61.1   57.0    729  4.34
#
#       y     z
# 0  4.18  2.40
# 1  6.53  3.99
# 2  6.36  3.95
# 3  6.48  3.92
# 4  7.94  4.80
# 5  6.84  4.12
# 6  6.00  3.66
# 7  7.51  4.64
# 8  6.41  4.00
# ...

# %%
# Split between Numerical Columns and Categorical Columns

data_inf_num = data_inf[num_columns]
data_inf_cat = data_inf[cat_columns]

data_inf_num
# Out:
#    carat  depth  table     x     y     z
# 0   0.25   57.6   60.0  4.15  4.18  2.40
# 1   1.03   60.7   60.0  6.61  6.53  3.99
# 2   1.01   61.6   61.0  6.46  6.36  3.95
# 3   1.00   60.2   58.0  6.55  6.48  3.92
# 4   1.78   60.6   57.0  7.89  7.94  4.80
# 5   1.20   60.0   61.0  6.89  6.84  4.12
# 6   0.78   61.2   54.0  5.96  6.00  3.66
# 7   1.61   62.0   58.0  7.46  7.51  4.64
# 8   1.00   62.7   58.0  6.35  6.41  4.00
# 9   0.31   61.1   57.0  4.34  4.36  2.66

# %%
# Feature Scaling and Feature Encoding

data_inf_num_scaled = scaler.transform(data_inf_num)
data_inf_cat_encoded = encoder.transform(data_inf_cat)
data_inf_num_scaled
# Out:
# array([[0.01272265, 0.40555556, 0.32692308, 0.40927022, 0.07096774,
#         0.0754717 ],
#        [0.21119593, 0.49166667, 0.32692308, 0.65187377, 0.11086587,
#         0.1254717 ],
#        [0.20610687, 0.51666667, 0.34615385, 0.63708087, 0.10797963,
#         0.12421384],
#        [0.20356234, 0.47777778, 0.28846154, 0.64595661, 0.11001698,
#         0.12327044],
#        [0.40203562, 0.48888889, 0.26923077, 0.77810651, 0.13480475,
#         0.1509434 ],
#        [0.25445293, 0.47222222, 0.34615385, 0.67948718, 0.11612903,
#         0.12955975],
#        [0.1475827 , 0.50555556, 0.21153846, 0.5877712 , 0.10186757,
#         0.11509434],
#        [0.35877863, 0.52777778, 0.28846154, 0.7357002 , 0.12750424,
#         0.14591195],
#        [0.20356234, 0.54722222, 0.28846154, 0.62623274, 0.10882852,
#         0.12578616],
#        [0.02798982, 0.50277778, 0.26923077, 0.42800789, 0.07402377,
#         0.0836478 ]])

# %%
# Concate Numerical Columns and Categorical Columns

data_inf_final = np.concatenate([data_inf_num_scaled, data_inf_cat_encoded], axis=1)
data_inf_final
# Out:
# array([[0.01272265, 0.40555556, 0.32692308, 0.40927022, 0.07096774,
#         0.0754717 , 1.        , 0.        , 4.        ],
#        [0.21119593, 0.49166667, 0.32692308, 0.65187377, 0.11086587,
#         0.1254717 , 3.        , 4.        , 2.        ],
#        [0.20610687, 0.51666667, 0.34615385, 0.63708087, 0.10797963,
#         0.12421384, 3.        , 3.        , 3.        ],
#        [0.20356234, 0.47777778, 0.28846154, 0.64595661, 0.11001698,
#         0.12327044, 3.        , 3.        , 1.        ],
#        [0.40203562, 0.48888889, 0.26923077, 0.77810651, 0.13480475,
#         0.1509434 , 2.        , 2.        , 2.        ],
#        [0.25445293, 0.47222222, 0.34615385, 0.67948718, 0.11612903,
#         0.12955975, 3.        , 6.        , 2.        ],
#        [0.1475827 , 0.50555556, 0.21153846, 0.5877712 , 0.10186757,
#         0.11509434, 4.        , 1.        , 1.        ],
#        [0.35877863, 0.52777778, 0.28846154, 0.7357002 , 0.12750424,
# ...

# %%
# Predict using Linear Regression

y_pred_inf = model_lin_reg.predict(data_inf_final)
y_pred_inf
# Out:
# array([  772.24736166,  4708.15044745,  5348.00710622,  4355.3067418 ,
#        12343.31269459,  5694.51074429,  3288.70292243,  9887.04006904,
#         3982.62191184,   753.87639706])

# %%
# Create DataFrame of Price's Prediction

y_pred_inf_df = pd.DataFrame(y_pred_inf, columns=['Price Prediction'])
y_pred_inf_df
# Out:
#    Price Prediction
# 0        772.247362
# 1       4708.150447
# 2       5348.007106
# 3       4355.306742
# 4      12343.312695
# 5       5694.510744
# 6       3288.702922
# 7       9887.040069
# 8       3982.621912
# 9        753.876397

# %%
# Concate between Inference-Set and Price's Prediction

data1 = pd.concat([data_inf, y_pred_inf_df], axis=1)
data1
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0       50617   0.25       Good     D     VS1   57.6   60.0    399  4.15
# 1        8291   1.03    Premium     H     SI1   60.7   60.0   4384  6.61
# 2       14521   1.01    Premium     G     VS2   61.6   61.0   5864  6.46
# 3        4276   1.00    Premium     G     SI2   60.2   58.0   3584  6.55
# 4       25116   1.78  Very Good     F     SI1   60.6   57.0  13659  7.89
# 5       10107   1.20    Premium     J     SI1   60.0   61.0   4717  6.89
# 6       52999   0.78      Ideal     E     SI2   61.2   54.0   2596  5.96
# 7       20739   1.61    Premium     I     SI1   62.0   58.0   8978  7.46
# 8        5244   1.00      Ideal     J     SI1   62.7   58.0   3788  6.35
# 9       30359   0.31      Ideal     F     VS1   61.1   57.0    729  4.34
#
#       y     z  Price Prediction
# 0  4.18  2.40        772.247362
# 1  6.53  3.99       4708.150447
# 2  6.36  3.95       5348.007106
# 3  6.48  3.92       4355.306742
# ...

# %%
data1.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'carat',
#  'cut',
#  'color',
#  'clarity',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z',
#  'Price Prediction']

# %%
data1[[ 'carat',
 'cut',
 'color',
 'clarity',
 'depth',
 'table',
 'price',
 'x',
 'y',
 'z',
 'Price Prediction']]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.25       Good     D     VS1   57.6   60.0    399  4.15  4.18  2.40
# 1   1.03    Premium     H     SI1   60.7   60.0   4384  6.61  6.53  3.99
# 2   1.01    Premium     G     VS2   61.6   61.0   5864  6.46  6.36  3.95
# 3   1.00    Premium     G     SI2   60.2   58.0   3584  6.55  6.48  3.92
# 4   1.78  Very Good     F     SI1   60.6   57.0  13659  7.89  7.94  4.80
# 5   1.20    Premium     J     SI1   60.0   61.0   4717  6.89  6.84  4.12
# 6   0.78      Ideal     E     SI2   61.2   54.0   2596  5.96  6.00  3.66
# 7   1.61    Premium     I     SI1   62.0   58.0   8978  7.46  7.51  4.64
# 8   1.00      Ideal     J     SI1   62.7   58.0   3788  6.35  6.41  4.00
# 9   0.31      Ideal     F     VS1   61.1   57.0    729  4.34  4.36  2.66
#
#    Price Prediction
# 0        772.247362
# 1       4708.150447
# 2       5348.007106
# 3       4355.306742
# 4      12343.312695
# 5       5694.510744
# ...
